# %% [markdown]
# # Module 6 Challenge
#
# ## 1. Retrieve Weather Data

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 605

# %%
# Import the request library.

import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.

city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.

record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the max temp, humidity, and cloudiness.
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate that the Data Loading is complete.

print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | san jeronimo
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | progreso
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | ust-uda
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | havre-saint-pierre
# Processing Record 9 of Set 1 | bhanpuri
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | rostovka
# Processing Record 13 of Set 1 | pitimbu
# Processing Record 14 of Set 1 | dalby
# Processing Record 15 of Set 1 | chake chake
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | hamilton
# Processing Record 19 of Set 1 | tabora
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | zhanaozen
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | sisimiut
# Processing Record 24 of Set 1 | byron bay
# Processing Record 25 of Set 1 | kiunga
# Processing Record 26 of Set 1 | berlevag
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | rio gallegos
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | cockburn town
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | iracoubo
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | eyl
# Processing Record 39 of Set 1 | comodoro rivadavia
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | montepuez
# Processing Record 43 of Set 1 | wadi musa
# Processing Record 44 of Set 1 | kerema
# Processing Record 45 of Set 1 | vao
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | nanakuli
# Processing Record 50 of Set 1 | srednekolymsk
# Processing Record 1 of Set 2 | axim
# Processing Record 2 of Set 2 | tabat
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | makokou
# Processing Record 6 of Set 2 | san antonio
# Processing Record 7 of Set 2 | ponta delgada
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | kyzyl
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | labuhan
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | owensboro
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | lebu
# Processing Record 21 of Set 2 | bibiani
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | san policarpo
# Processing Record 24 of Set 2 | general pico
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | vila
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | wuwei
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | petrokamenskoye
# Processing Record 31 of Set 2 | leningradskiy
# Processing Record 32 of Set 2 | makakilo city
# Processing Record 33 of Set 2 | savinka
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | palembang
# Processing Record 36 of Set 2 | lethem
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | natal
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | elko
# Processing Record 41 of Set 2 | sorland
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | la ronge
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | usinsk
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | urumqi
# Processing Record 49 of Set 2 | caravelas
# Processing Record 50 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | bima
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | malanje
# Processing Record 7 of Set 3 | cabo san lucas
# Processing Record 8 of Set 3 | rocha
# Processing Record 9 of Set 3 | grindavik
# Processing Record 10 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | ionia
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | portsoy
# Processing Record 16 of Set 3 | severo-kurilsk
# Processing Record 17 of Set 3 | tevaitoa
# Processing Record 18 of Set 3 | sycamore
# Processing Record 19 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 3 | lufilufi
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 3 | rayagada
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | dorchester
# Processing Record 28 of Set 3 | atar
# Processing Record 29 of Set 3 | richards bay
# Processing Record 30 of Set 3 | simao
# Processing Record 31 of Set 3 | san jose
# Processing Record 32 of Set 3 | mwinilunga
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | the valley
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | the pas
# Processing Record 37 of Set 3 | paamiut
# Processing Record 38 of Set 3 | behshahr
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | korla
# Processing Record 42 of Set 3 | kumluca
# Processing Record 43 of Set 3 | chunhuhub
# Processing Record 44 of Set 3 | malinovskiy
# Processing Record 45 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 3 | muroto
# Processing Record 47 of Set 3 | waipawa
# Processing Record 48 of Set 3 | sarankhola
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | tuktoyaktuk
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | itamaraca
# Processing Record 4 of Set 4 | xadani
# City not found. Skipping...
# Processing Record 5 of Set 4 | gat
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | hammerfest
# Processing Record 8 of Set 4 | ordynskoye
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | dunda
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 4 | de-kastri
# Processing Record 14 of Set 4 | zalantun
# Processing Record 15 of Set 4 | saint-augustin
# Processing Record 16 of Set 4 | matara
# Processing Record 17 of Set 4 | porto torres
# Processing Record 18 of Set 4 | mackay
# Processing Record 19 of Set 4 | hessisch oldendorf
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | linxia
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | huadian
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | lalmohan
# Processing Record 28 of Set 4 | glendive
# Processing Record 29 of Set 4 | rivadavia
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | road town
# Processing Record 32 of Set 4 | georgetown
# Processing Record 33 of Set 4 | sept-iles
# Processing Record 34 of Set 4 | bilma
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | netivot
# Processing Record 37 of Set 4 | sharanga
# Processing Record 38 of Set 4 | saiha
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | shebunino
# Processing Record 42 of Set 4 | fuenlabrada
# Processing Record 43 of Set 4 | andrews
# Processing Record 44 of Set 4 | kardonikskaya
# Processing Record 45 of Set 4 | yumen
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | alofi
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | kaeo
# Processing Record 50 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | mayskiy
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | fort nelson
# Processing Record 6 of Set 5 | beyla
# Processing Record 7 of Set 5 | freeport
# Processing Record 8 of Set 5 | koson
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | aksarka
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | le port
# Processing Record 13 of Set 5 | agadir
# Processing Record 14 of Set 5 | flin flon
# Processing Record 15 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 16 of Set 5 | bairiki
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | margate
# Processing Record 21 of Set 5 | tres coroas
# Processing Record 22 of Set 5 | uroteppa
# City not found. Skipping...
# Processing Record 23 of Set 5 | pahrump
# Processing Record 24 of Set 5 | gamba
# Processing Record 25 of Set 5 | pishchanka
# City not found. Skipping...
# Processing Record 26 of Set 5 | guanare
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | anyang
# Processing Record 29 of Set 5 | vanavara
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | westport
# Processing Record 32 of Set 5 | komsomolskiy
# Processing Record 33 of Set 5 | anadyr
# Processing Record 34 of Set 5 | kishtwar
# Processing Record 35 of Set 5 | menongue
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | tobol
# Processing Record 39 of Set 5 | marsabit
# Processing Record 40 of Set 5 | saint-joseph
# Processing Record 41 of Set 5 | ensenada
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | ochiltree
# Processing Record 45 of Set 5 | ipixuna
# Processing Record 46 of Set 5 | bandarbeyla
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | goderich
# Processing Record 49 of Set 5 | banepa
# Processing Record 50 of Set 5 | vera cruz
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | kudahuvadhoo
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | los llanos de aridane
# Processing Record 5 of Set 6 | copiapo
# Processing Record 6 of Set 6 | touros
# Processing Record 7 of Set 6 | lazaro cardenas
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | abu samrah
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | asau
# Processing Record 12 of Set 6 | elmadag
# Processing Record 13 of Set 6 | illapel
# Processing Record 14 of Set 6 | egvekinot
# Processing Record 15 of Set 6 | lompoc
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | jinchang
# Processing Record 18 of Set 6 | ixtapa
# Processing Record 19 of Set 6 | flagstaff
# Processing Record 20 of Set 6 | victoria
# Processing Record 21 of Set 6 | vardo
# Processing Record 22 of Set 6 | hurghada
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | hami
# Processing Record 25 of Set 6 | changde
# Processing Record 26 of Set 6 | zeya
# Processing Record 27 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | birjand
# Processing Record 29 of Set 6 | tuatapere
# Processing Record 30 of Set 6 | lata
# Processing Record 31 of Set 6 | rudbar
# Processing Record 32 of Set 6 | oriximina
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | tongliao
# Processing Record 35 of Set 6 | coihaique
# Processing Record 36 of Set 6 | hlotse
# Processing Record 37 of Set 6 | tumba
# Processing Record 38 of Set 6 | meulaboh
# Processing Record 39 of Set 6 | muisne
# Processing Record 40 of Set 6 | manicore
# Processing Record 41 of Set 6 | dauphin
# Processing Record 42 of Set 6 | pryazha
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | makaha
# Processing Record 46 of Set 6 | san vicente
# Processing Record 47 of Set 6 | mogadouro
# Processing Record 48 of Set 6 | yining
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | cherskiy
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | jahangirpur
# Processing Record 3 of Set 7 | santa lucia
# Processing Record 4 of Set 7 | hay river
# Processing Record 5 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 7 | ciparay
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | barcelos
# Processing Record 11 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 12 of Set 7 | irbeyskoye
# Processing Record 13 of Set 7 | concepcion del oro
# Processing Record 14 of Set 7 | awjilah
# Processing Record 15 of Set 7 | artesia
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | mandalgovi
# Processing Record 18 of Set 7 | airai
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | mvuma
# Processing Record 21 of Set 7 | fleetwood
# Processing Record 22 of Set 7 | elk river
# Processing Record 23 of Set 7 | shimoda
# Processing Record 24 of Set 7 | anchorage
# Processing Record 25 of Set 7 | tahoua
# Processing Record 26 of Set 7 | upata
# Processing Record 27 of Set 7 | high level
# Processing Record 28 of Set 7 | wheeling
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | danane
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 7 | bendigo
# Processing Record 33 of Set 7 | hilo
# Processing Record 34 of Set 7 | kalevala
# Processing Record 35 of Set 7 | aranda de duero
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | okhotsk
# Processing Record 40 of Set 7 | west wendover
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | south lake tahoe
# Processing Record 43 of Set 7 | lavumisa
# Processing Record 44 of Set 7 | raudeberg
# Processing Record 45 of Set 7 | san estanislao
# Processing Record 46 of Set 7 | tondano
# Processing Record 47 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 7 | sindor
# Processing Record 49 of Set 7 | minab
# Processing Record 50 of Set 7 | hue
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | lewistown
# Processing Record 5 of Set 8 | rundu
# Processing Record 6 of Set 8 | natchitoches
# Processing Record 7 of Set 8 | barra do garcas
# Processing Record 8 of Set 8 | posse
# Processing Record 9 of Set 8 | stokmarknes
# Processing Record 10 of Set 8 | ahtopol
# Processing Record 11 of Set 8 | kidal
# Processing Record 12 of Set 8 | payo
# Processing Record 13 of Set 8 | mogzon
# Processing Record 14 of Set 8 | luba
# Processing Record 15 of Set 8 | brae
# Processing Record 16 of Set 8 | beira
# Processing Record 17 of Set 8 | ambilobe
# Processing Record 18 of Set 8 | country club
# Processing Record 19 of Set 8 | morondava
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | san cristobal
# Processing Record 23 of Set 8 | bull savanna
# Processing Record 24 of Set 8 | port hardy
# Processing Record 25 of Set 8 | arroyos y esteros
# Processing Record 26 of Set 8 | kano
# Processing Record 27 of Set 8 | tome-acu
# City not found. Skipping...
# Processing Record 28 of Set 8 | santa rosa
# Processing Record 29 of Set 8 | kushima
# Processing Record 30 of Set 8 | praxedis guerrero
# Processing Record 31 of Set 8 | san javier
# Processing Record 32 of Set 8 | voh
# Processing Record 33 of Set 8 | tokmak
# Processing Record 34 of Set 8 | hualmay
# Processing Record 35 of Set 8 | bakel
# Processing Record 36 of Set 8 | clyde river
# Processing Record 37 of Set 8 | tabory
# Processing Record 38 of Set 8 | saint anthony
# Processing Record 39 of Set 8 | yeppoon
# Processing Record 40 of Set 8 | portland
# Processing Record 41 of Set 8 | baykit
# Processing Record 42 of Set 8 | taltal
# Processing Record 43 of Set 8 | give
# Processing Record 44 of Set 8 | palm valley
# Processing Record 45 of Set 8 | yerbogachen
# Processing Record 46 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 8 | emerald
# Processing Record 48 of Set 8 | tambopata
# Processing Record 49 of Set 8 | maragogi
# Processing Record 50 of Set 8 | kuopio
# Processing Record 1 of Set 9 | antalaha
# Processing Record 2 of Set 9 | half moon bay
# Processing Record 3 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 9 | tiksi
# Processing Record 5 of Set 9 | bichena
# Processing Record 6 of Set 9 | huicheng
# Processing Record 7 of Set 9 | pailon
# Processing Record 8 of Set 9 | viedma
# Processing Record 9 of Set 9 | ahipara
# Processing Record 10 of Set 9 | beloha
# Processing Record 11 of Set 9 | sur
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | waddan
# Processing Record 14 of Set 9 | soyo
# Processing Record 15 of Set 9 | olinda
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | sola
# Processing Record 18 of Set 9 | cape canaveral
# Processing Record 19 of Set 9 | new amsterdam
# Processing Record 20 of Set 9 | pisco
# Processing Record 21 of Set 9 | honiara
# Processing Record 22 of Set 9 | arica
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | muscle shoals
# Processing Record 25 of Set 9 | phalaborwa
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | chipata
# Processing Record 28 of Set 9 | monrovia
# Processing Record 29 of Set 9 | alice springs
# Processing Record 30 of Set 9 | povoa de varzim
# Processing Record 31 of Set 9 | greenwood
# Processing Record 32 of Set 9 | deer lake
# Processing Record 33 of Set 9 | abhar
# Processing Record 34 of Set 9 | mindelo
# Processing Record 35 of Set 9 | guangyuan
# Processing Record 36 of Set 9 | karratha
# Processing Record 37 of Set 9 | point pedro
# Processing Record 38 of Set 9 | formosa
# Processing Record 39 of Set 9 | grand gaube
# Processing Record 40 of Set 9 | whitley bay
# Processing Record 41 of Set 9 | kimi
# City not found. Skipping...
# Processing Record 42 of Set 9 | antigonish
# Processing Record 43 of Set 9 | aswan
# Processing Record 44 of Set 9 | toora-khem
# Processing Record 45 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 9 | elat
# Processing Record 47 of Set 9 | port lincoln
# Processing Record 48 of Set 9 | taoudenni
# Processing Record 49 of Set 9 | mweka
# Processing Record 50 of Set 9 | kota kinabalu
# Processing Record 1 of Set 10 | saint-louis
# Processing Record 2 of Set 10 | champerico
# Processing Record 3 of Set 10 | maumere
# Processing Record 4 of Set 10 | mahon
# Processing Record 5 of Set 10 | labuan
# Processing Record 6 of Set 10 | villeneuve-sur-lot
# Processing Record 7 of Set 10 | bafra
# Processing Record 8 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 10 | dieppe bay
# City not found. Skipping...
# Processing Record 10 of Set 10 | vozuca
# Processing Record 11 of Set 10 | santa vitoria do palmar
# Processing Record 12 of Set 10 | yokadouma
# Processing Record 13 of Set 10 | laguna
# Processing Record 14 of Set 10 | nhamunda
# Processing Record 15 of Set 10 | kodinsk
# Processing Record 16 of Set 10 | teya
# Processing Record 17 of Set 10 | salta
# Processing Record 18 of Set 10 | necochea
# Processing Record 19 of Set 10 | puerto colombia
# Processing Record 20 of Set 10 | ballina
# Processing Record 21 of Set 10 | limon
# Processing Record 22 of Set 10 | te anau
# Processing Record 23 of Set 10 | inhambane
# Processing Record 24 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 10 | pastavy
# Processing Record 26 of Set 10 | boa vista
# Processing Record 27 of Set 10 | namtsy
# Processing Record 28 of Set 10 | college
# Processing Record 29 of Set 10 | rambha
# Processing Record 30 of Set 10 | hervey bay
# Processing Record 31 of Set 10 | kibala
# Processing Record 32 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 10 | tumkur
# Processing Record 34 of Set 10 | uyar
# Processing Record 35 of Set 10 | surgut
# Processing Record 36 of Set 10 | tavai
# City not found. Skipping...
# Processing Record 37 of Set 10 | samarai
# Processing Record 38 of Set 10 | mpika
# Processing Record 39 of Set 10 | kinshasa
# Processing Record 40 of Set 10 | concordia
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | taunggyi
# Processing Record 44 of Set 10 | folldal
# Processing Record 45 of Set 10 | svetlyy
# Processing Record 46 of Set 10 | shostka
# Processing Record 47 of Set 10 | salto
# Processing Record 48 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 49 of Set 10 | san luis
# Processing Record 50 of Set 10 | storm lake
# Processing Record 1 of Set 11 | ormara
# Processing Record 2 of Set 11 | lokosovo
# Processing Record 3 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 11 | mporokoso
# Processing Record 5 of Set 11 | takoradi
# Processing Record 6 of Set 11 | nur
# Processing Record 7 of Set 11 | genhe
# Processing Record 8 of Set 11 | manggar
# Processing Record 9 of Set 11 | betong
# Processing Record 10 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 11 | hunterville
# Processing Record 12 of Set 11 | cahors
# Processing Record 13 of Set 11 | mildura
# Processing Record 14 of Set 11 | mayo
# Processing Record 15 of Set 11 | bathsheba
# Processing Record 16 of Set 11 | pokrovskoye
# Processing Record 17 of Set 11 | lumberton
# Processing Record 18 of Set 11 | galle
# Processing Record 19 of Set 11 | augustow
# Processing Record 20 of Set 11 | krasnovishersk
# Processing Record 21 of Set 11 | almaznyy
# Processing Record 22 of Set 11 | acari
# Processing Record 23 of Set 11 | miles city
# Processing Record 24 of Set 11 | griffith
# Processing Record 25 of Set 11 | tautira
# Processing Record 26 of Set 11 | victoria point
# Processing Record 27 of Set 11 | poitiers
# Processing Record 28 of Set 11 | luderitz
# Processing Record 29 of Set 11 | butterworth
# Processing Record 30 of Set 11 | cairns
# Processing Record 31 of Set 11 | vostok
# Processing Record 32 of Set 11 | nicoya
# Processing Record 33 of Set 11 | mehamn
# Processing Record 34 of Set 11 | stromness
# Processing Record 35 of Set 11 | bafoulabe
# Processing Record 36 of Set 11 | corn island
# Processing Record 37 of Set 11 | taksimo
# Processing Record 38 of Set 11 | lake havasu city
# Processing Record 39 of Set 11 | hyeres
# Processing Record 40 of Set 11 | camacha
# Processing Record 41 of Set 11 | inuvik
# Processing Record 42 of Set 11 | laurentides
# Processing Record 43 of Set 11 | varhaug
# Processing Record 44 of Set 11 | papasquiaro
# City not found. Skipping...
# Processing Record 45 of Set 11 | puerto carreno
# Processing Record 46 of Set 11 | sibolga
# Processing Record 47 of Set 11 | chara
# Processing Record 48 of Set 11 | bowen
# Processing Record 49 of Set 11 | cheney
# Processing Record 50 of Set 11 | tucuman
# Processing Record 1 of Set 12 | talnakh
# Processing Record 2 of Set 12 | bloomingdale
# Processing Record 3 of Set 12 | kachug
# Processing Record 4 of Set 12 | okha
# Processing Record 5 of Set 12 | mazagao
# Processing Record 6 of Set 12 | ampanihy
# Processing Record 7 of Set 12 | pandamatenga
# Processing Record 8 of Set 12 | astrakhan
# Processing Record 9 of Set 12 | valparaiso
# Processing Record 10 of Set 12 | beringovskiy
# Processing Record 11 of Set 12 | ewa beach
# Processing Record 12 of Set 12 | magadan
# Processing Record 13 of Set 12 | gimbi
# Processing Record 14 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 12 | hunchun
# Processing Record 16 of Set 12 | atka
# City not found. Skipping...
# Processing Record 17 of Set 12 | akyab
# Processing Record 18 of Set 12 | devyatka
# City not found. Skipping...
# Processing Record 19 of Set 12 | santa fe
# Processing Record 20 of Set 12 | kushiro
# Processing Record 21 of Set 12 | rosamorada
# Processing Record 22 of Set 12 | arkhangelsk
# Processing Record 23 of Set 12 | colares
# Processing Record 24 of Set 12 | yongan
# Processing Record 25 of Set 12 | buraydah
# Processing Record 26 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 12 | liverpool
# Processing Record 28 of Set 12 | innisfail
# Processing Record 29 of Set 12 | sovetskiy
# Processing Record 30 of Set 12 | blacksburg
# Processing Record 31 of Set 12 | buala
# Processing Record 32 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 12 | najran
# Processing Record 34 of Set 12 | kolyvan
# Processing Record 35 of Set 12 | tahta
# Processing Record 36 of Set 12 | north myrtle beach
# Processing Record 37 of Set 12 | manta
# Processing Record 38 of Set 12 | bonthe
# Processing Record 39 of Set 12 | broome
# Processing Record 40 of Set 12 | beisfjord
# Processing Record 41 of Set 12 | kiama
# Processing Record 42 of Set 12 | palmer
# Processing Record 43 of Set 12 | visby
# Processing Record 44 of Set 12 | syracuse
# Processing Record 45 of Set 12 | mitu
# Processing Record 46 of Set 12 | hambantota
# Processing Record 47 of Set 12 | cutervo
# Processing Record 48 of Set 12 | belyy yar
# Processing Record 49 of Set 12 | mosquera
# Processing Record 50 of Set 12 | sembakung
# Processing Record 1 of Set 13 | sao jose da coroa grande
# Processing Record 2 of Set 13 | polunochnoye
# Processing Record 3 of Set 13 | mandera
# Processing Record 4 of Set 13 | lasa
# Processing Record 5 of Set 13 | leh
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 555

# %%
# convert list of dictionaries to a pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp Current Description  \
# 0             ushuaia -54.8000  -68.3000     26.26          few clouds
# 1        san jeronimo -11.9472  -75.2829     52.09       broken clouds
# 2           busselton -33.6500  115.3333     58.62       broken clouds
# 3            progreso  21.2833  -89.6667     81.10          few clouds
# 4               vaini -21.2000 -175.2000     75.36          few clouds
# 5             ust-uda  54.1742  103.0304     52.92       moderate rain
# 6              hobart -42.8794  147.3294     44.46          light rain
# 7  havre-saint-pierre  50.2334  -63.5986     61.16       broken clouds
# 8            bhanpuri  21.1000   80.9167     77.86     overcast clouds
# 9            khatanga  71.9667  102.5000     59.34          few clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00              0        80          20        5.75      AR
# 1           0.00              0        54          74        1.81      PE
# 2           0.00              0        73          84        3.11      AU
# 3           0.00              0        72          14        9.17      MX
# 4           0.00              0        94          20        9.22      TO
# 5           1.76              0        97         100        5.66      RU
# 6           0.33              0        86         100       14.97      AU
# 7           0.00              0        77          75        5.75      CA
# 8           0.00              0        90         100        8.59      IN
# 9           0.00              0        52          21        4.97      RU

# %%
# Reorder the columns in the order you want them to appear.

new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description', 
                    'Rain (inches)', 'Snow (inches)']

# Assign a new or the same DataFrame the new column order.

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             ushuaia      AR -54.8000  -68.3000     26.26        80
# 1        san jeronimo      PE -11.9472  -75.2829     52.09        54
# 2           busselton      AU -33.6500  115.3333     58.62        73
# 3            progreso      MX  21.2833  -89.6667     81.10        72
# 4               vaini      TO -21.2000 -175.2000     75.36        94
# 5             ust-uda      RU  54.1742  103.0304     52.92        97
# 6              hobart      AU -42.8794  147.3294     44.46        86
# 7  havre-saint-pierre      CA  50.2334  -63.5986     61.16        77
# 8            bhanpuri      IN  21.1000   80.9167     77.86        90
# 9            khatanga      RU  71.9667  102.5000     59.34        52
#
#    Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0          20        5.75          few clouds           0.00              0
# 1          74        1.81       broken clouds           0.00              0
# 2          84        3.11       broken clouds           0.00              0
# 3          14        9.17          few clouds           0.00              0
# 4          20        9.22          few clouds           0.00              0
# 5         100        5.66       moderate rain           1.76              0
# 6         100       14.97          light rain           0.33              0
# 7          75        5.75       broken clouds           0.00              0
# 8         100        8.59     overcast clouds           0.00              0
# 9          21        4.97          few clouds           0.00              0

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
raining_cities.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 5       ust-uda      RU  54.1742  103.0304     52.92        97         100
# 6        hobart      AU -42.8794  147.3294     44.46        86         100
# 14  chake chake      TZ  -5.2459   39.7666     75.38        83          84
# 49         axim      GH   4.8699   -2.2405     78.73        78          92
# 51     tasiilaq      GL  65.6145  -37.6368     46.56        65         100
#
#     Wind Speed Current Description  Rain (inches)  Snow (inches)
# 5         5.66       moderate rain           1.76              0
# 6        14.97          light rain           0.33              0
# 14       15.05          light rain           0.81              0
# 49       12.26          light rain           0.12              0
# 51       23.33          light rain           0.27              0

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
snowing_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).

output_data_file = 'Weather_Database/WeatherPy_database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
